# %%
import pandas as pd

# %%
players = pd.read_csv("/home/emkay/PycharmProjects/temp/ipl_players.csv" )

# %%
players.columns
# Out:
# Index(['MI', 'csk', 'rcb', 'dc', 'kkr', 'RR', 'kixp', 'srh'], dtype='object')

# %% [markdown]
# ##### HIstory

# %%
ipl_hist = pd.read_csv("/home/emkay/PycharmProjects/temp/deliveries.csv")

# %%
ipl_hist.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
MI_TEAM = players['MI'].values.tolist()

# %%
print(len(MI_TEAM))
# Out:
# 25

# %%
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process

# %%
# PLAYER =[]
# TEAM = []
# for team in players.columns.tolist():
#     for val in players[team].values.tolist():
#         if process.extractOne(val,ipl_hist['batsman'].unique().tolist())[1] > 40:
#             PLAYER.append(process.extractOne(val,ipl_hist['batsman'].unique().tolist())[0])
#             TEAM.append(team)
# df = pd.DataFrame({"players":PLAYER,"team":TEAM})

# %%
#current_team = df.drop_duplicates()

# %%
#current_team['team'].unique()
# Out:
# array(['MI', 'csk', 'rcb', 'dc', 'kkr', 'RR', 'kixp', 'srh'], dtype=object)

# %%
current_team = pd.read_csv("team_ipl_2019.csv",index=False)

# %% [markdown]
# ### CURRENT MATCH BEGINS

# %%
# match between srh x11p
team1 = current_team.loc[current_team['team']=='srh']
team2 = current_team.loc[current_team['team']=='kixp']
the_team = pd.concat([team1,team2])

# %%
ipl_hist.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
ipl_hist = ipl_hist[['batsman','non_striker','bowler','batsman_runs','player_dismissed','dismissal_kind','fielder']]

# %%
ipl_hist = ipl_hist.loc[ipl_hist['batsman'].isin(the_team['players'])]

# %%
ipl_hist = ipl_hist.fillna(0)

# %%
ipl_hist
# Out:
#           batsman     non_striker             bowler  batsman_runs  \
# 185       P Kumar       AA Noffke         SC Ganguly             0
# 186       P Kumar       AA Noffke         SC Ganguly             0
# 187       P Kumar       AA Noffke         SC Ganguly             0
# 188       P Kumar       AA Noffke         SC Ganguly             0
# 195       P Kumar       AA Noffke         AB Agarkar             4
# 196       P Kumar       AA Noffke         AB Agarkar             0
# 198        Z Khan         P Kumar         SC Ganguly             0
# 199        Z Khan         P Kumar         SC Ganguly             0
# 200        Z Khan         P Kumar         SC Ganguly             1
# 201       P Kumar          Z Khan         SC Ganguly             0
# 202       P Kumar          Z Khan         SC Ganguly             1
# 203       P Kumar          Z Khan          LR Shukla             6
# 204       P Kumar          Z Khan          LR Shukla             0
# 205        Z Khan         P Kumar          LR Shukla             1
# 206       P Kumar          Z Khan          LR Shukla             1
# 207        Z Khan         P Kumar          LR Shukla             0
# 208        Z Khan         P Kumar          LR Shukla             0
# 209        Z Khan         P Kumar          LR Shukla             1
# 210        Z Khan         P Kumar         SC Ganguly             0
# 212       P Kumar        SB Joshi         SC Ganguly             0
# 213       P Kumar        SB Joshi         SC Ganguly             0
# 214       P Kumar        SB Joshi         SC Ganguly             0
# 215       P Kumar        SB Joshi         SC Ganguly             6
# 220       P Kumar        SB Joshi           I Sharma             0
# 222       P Kumar        SB Joshi           I Sharma             0
# 460     IK Pathan       SM Katich     M Muralitharan             0
